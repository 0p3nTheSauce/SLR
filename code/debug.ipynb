# %%
_spec = {
    "training": {
        "batch_size": 4,
        "update_per_step": 2,
        "max_epoch": 200
    },
    "optimizer": {
        "eps": 1e-05,
        "backbone_init_lr": 0.0001,
        "backbone_weight_decay": 0.001,
        "classifier_init_lr": 0.001,
        "classifier_weight_decay": 0.001
    },
    "model_params": {
        "drop_p": 0.5
    },
    "scheduler": {
        "type": "CosineAnnealingWarmRestarts",
        "t0": 20,
        "tmult": 1,
        "eta_min": 0
    },
    "data": {
        "train_augs": {
            "normalise": True,
            "temporal_aug": [
                {
                    "type": "chunked",
                    "target_length": 16
                }
            ],
            "spatial_aug": [
                {
                    "type": "HORIZONTAL_FLIP",
                    "p": 0.5
                },
                {
                    "type": "Centre_crop",
                    "frame_size": 224
                },
                {
                    "type": "RANDAUGMENT",
                    "num_ops": 3,
                    "magnitude": 7,
                    "num_magnitude_bins": 31,
                    "interpolation": "bilinear"
                }
            ]
        },
        "test_augs": {
            "normalise": True,
            "temporal_aug": [
                {
                    "type": "uniform",
                    "target_length": 16
                }
            ],
            "spatial_aug": [
                {
                    "type": "Centre_crop",
                    "frame_size": 224
                }
            ]
        }
    },
    "early_stopping": {
        "metric": [
            "val",
            "loss"
        ],
        "mode": "min",
        "patience": 15,
        "min_delta": 0.01
    }
}

# %%
_search = {
            "admin": {
                "model": "MViTv2_S",
                "dataset": "WLASL",
                "split": "asl100",
                "save_path": "runs/asl100/MViTv2_S/exp014/checkpoints",
                "seed": 42,
                "exp_no": "014",
                "recover": False,
                "config_path": "configfiles/asl100/MViTv2_S/exp014.ini",
                "weight_path": None
            },
            "training": {
                "batch_size": 4,
                "update_per_step": 2,
                "max_epoch": 200,
                "batch_size_equivalent": 8
            },
            "optimizer": {
                "eps": 1e-05,
                "backbone_init_lr": 0.0001,
                "backbone_weight_decay": 0.001,
                "classifier_init_lr": 0.001,
                "classifier_weight_decay": 0.001
            },
            "model_params": {
                "drop_p": 0.5,
                "type": "supervised"
            },
            "data": {
                "train_augs": {
                    "normalise": True,
                    "norm_dict": {
                        "mean": [
                            0.45,
                            0.45,
                            0.45
                        ],
                        "std": [
                            0.225,
                            0.225,
                            0.225
                        ]
                    },
                    "temporal_aug": [
                        {
                            "target_length": 16,
                            "max_wobble": 0,
                            "type": "og",
                            "randomise": False
                        }
                    ],
                    "spatial_aug": [
                        {
                            "frame_size": 224,
                            "type": "Random_crop"
                        },
                        {
                            "type": "HORIZONTAL_FLIP",
                            "p": 0.5
                        }
                    ],
                    "strict_size": False,
                    "target_length": 16,
                    "frame_size": 224
                },
                "test_augs": {
                    "normalise": False,
                    "norm_dict": {
                        "mean": [
                            0.45,
                            0.45,
                            0.45
                        ],
                        "std": [
                            0.225,
                            0.225,
                            0.225
                        ]
                    },
                    "temporal_aug": [
                        {
                            "target_length": 16,
                            "max_wobble": 0,
                            "type": "og",
                            "randomise": False
                        }
                    ],
                    "spatial_aug": [
                        {
                            "frame_size": 224,
                            "type": "Centre_crop"
                        }
                    ],
                    "strict_size": False,
                    "target_length": 16,
                    "frame_size": 224
                },
                "strict_size": False,
                "target_length": 16,
                "frame_size": 224
            },
            "scheduler": False,
            "early_stopping": {
                "metric": [
                    "val",
                    "loss"
                ],
                "mode": "min",
                "patience": 15,
                "min_delta": 0.01
            },
            "wandb": {
                "entity": "ljgoodall2001-rhodes-university",
                "project": "WLASL-100",
                "tags": [
                    "asl100",
                    "MViTv2_S",
                    "exp-14",
                    "compare_to_11"
                ],
                "run_id": "mwjmw201"
            },
            "results": {
                "check_name": "best_val",
                "best_val_acc": 76.33136094674556,
                "best_val_loss": 0.9702750762570485,
                "test": {
                    "top_k_average_per_class_acc": {
                        "top1": 0.7134999999999999,
                        "top5": 0.9279999999999999,
                        "top10": 0.9583333333333333
                    },
                    "top_k_per_instance_acc": {
                        "top1": 0.7093023255813954,
                        "top5": 0.9224806201550387,
                        "top10": 0.9573643410852714
                    },
                    "average_loss": 1.1145970256784352
                },
                "val": {
                    "top_k_average_per_class_acc": {
                        "top1": 0.7263333333333333,
                        "top5": 0.9333333333333332,
                        "top10": 0.9616666666666667
                    },
                    "top_k_per_instance_acc": {
                        "top1": 0.7248520710059172,
                        "top5": 0.9319526627218935,
                        "top10": 0.9615384615384616
                    },
                    "average_loss": 0.9702750762570485
                },
                "test_shuff": {
                    "top_k_average_per_class_acc": {
                        "top1": 0.48083333333333333,
                        "top5": 0.8491666666666666,
                        "top10": 0.9008333333333333
                    },
                    "top_k_per_instance_acc": {
                        "top1": 0.4806201550387597,
                        "top5": 0.8410852713178295,
                        "top10": 0.8953488372093024
                    },
                    "average_loss": 2.0525671644551435,
                    "perm": [
                        6,
                        3,
                        0,
                        7,
                        10,
                        15,
                        2,
                        12,
                        14,
                        9,
                        8,
                        5,
                        4,
                        13,
                        11,
                        1
                    ],
                    "shannon_entropy": 3.327819585800171
                }
            }
        }

# %%
_search_match = {"admin": {
                "model": "MViTv2_S",
                "dataset": "WLASL",
                "split": "asl100_worst",
                "save_path": "runs/asl100_worst/MViTv2_S/exp000/checkpoints",
                "seed": 42,
                "exp_no": "000",
                "recover": False,
                "config_path": "configfiles/asl100/MViTv2_S/exp016.toml",
                "weight_path": None
            },
            "training": {
                "batch_size": 4,
                "update_per_step": 2,
                "max_epoch": 200,
                "batch_size_equivalent": 8
            },
            "optimizer": {
                "eps": 1e-05,
                "backbone_init_lr": 0.0001,
                "backbone_weight_decay": 0.001,
                "classifier_init_lr": 0.001,
                "classifier_weight_decay": 0.001
            },
            "model_params": {
                "drop_p": 0.5,
                "type": "supervised"
            },
            "data": {
                "train_augs": {
                    "normalise": True,
                    "norm_dict": {
                        "mean": [
                            0.45,
                            0.45,
                            0.45
                        ],
                        "std": [
                            0.225,
                            0.225,
                            0.225
                        ]
                    },
                    "temporal_aug": [
                        {
                            "target_length": 16,
                            "max_wobble": 4,
                            "type": "chunked"
                        }
                    ],
                    "spatial_aug": [
                        {
                            "type": "HORIZONTAL_FLIP",
                            "p": 0.5
                        },
                        {
                            "frame_size": 224,
                            "type": "Centre_crop"
                        },
                        {
                            "type": "RANDAUGMENT",
                            "num_ops": 3,
                            "magnitude": 7,
                            "num_magnitude_bins": 31,
                            "interpolation": "bilinear"
                        }
                    ],
                    "strict_size": True,
                    "target_length": 16,
                    "frame_size": 224
                },
                "test_augs": {
                    "normalise": True,
                    "norm_dict": {
                        "mean": [
                            0.45,
                            0.45,
                            0.45
                        ],
                        "std": [
                            0.225,
                            0.225,
                            0.225
                        ]
                    },
                    "temporal_aug": [
                        {
                            "target_length": 16,
                            "max_wobble": 0,
                            "type": "uniform"
                        }
                    ],
                    "spatial_aug": [
                        {
                            "frame_size": 224,
                            "type": "Centre_crop"
                        }
                    ],
                    "strict_size": True,
                    "target_length": 16,
                    "frame_size": 224
                },
                "strict_size": True,
                "target_length": 16,
                "frame_size": 224
            },
            "scheduler": {
                "warm_up": None,
                "type": "CosineAnnealingWarmRestarts",
                "t0": 20,
                "tmult": 1,
                "eta_min": 0.0
            },
            "early_stopping": {
                "metric": [
                    "val",
                    "loss"
                ],
                "mode": "min",
                "patience": 15,
                "min_delta": 0.01
            },
            "wandb": {
                "entity": "ljgoodall2001-rhodes-university",
                "project": "WLASL-100_worst",
                "tags": [],
                "run_id": "v5hi3fz0"
            },
            "results": {
                "check_name": "best_val",
                "best_val_acc": 61.1764705882353,
                "best_val_loss": 1.395684665708127,
                "test": {
                    "top_k_average_per_class_acc": {
                        "top1": 0.5591666666666666,
                        "top5": 0.8358333333333333,
                        "top10": 0.9025
                    },
                    "top_k_per_instance_acc": {
                        "top1": 0.5566037735849056,
                        "top5": 0.8349056603773585,
                        "top10": 0.9009433962264151
                    },
                    "average_loss": 1.823003733574571
                },
                "val": {
                    "top_k_average_per_class_acc": {
                        "top1": 0.615,
                        "top5": 0.8958333333333333,
                        "top10": 0.9666666666666666
                    },
                    "top_k_per_instance_acc": {
                        "top1": 0.6039215686274509,
                        "top5": 0.8862745098039215,
                        "top10": 0.9647058823529412
                    },
                    "average_loss": 1.395684665708127
                },
                "test_shuff": {
                    "top_k_average_per_class_acc": {
                        "top1": 0.35916666666666663,
                        "top5": 0.6766666666666665,
                        "top10": 0.8275
                    },
                    "top_k_per_instance_acc": {
                        "top1": 0.35377358490566035,
                        "top5": 0.6745283018867925,
                        "top10": 0.8254716981132075
                    },
                    "average_loss": 2.7754944896672518,
                    "perm": [
                        6,
                        3,
                        0,
                        7,
                        10,
                        15,
                        2,
                        12,
                        14,
                        9,
                        8,
                        5,
                        4,
                        13,
                        11,
                        1
                    ],
                    "shannon_entropy": 3.327819585800171
                }
            }
        }

# %%
from typing import Any
import logging
def _snap_dict(search: dict, spec: dict) -> bool:
    """values of spec == values of search"""
    return all(search[k] == v for k, v in spec.items())

def _snap_list_dict(search: list[dict], spec: list[dict]) -> bool:
    """dict values in spec == those in search"""
    return all(_snap_dict(s, c) for s, c in zip(search, spec))


def _has_dict(x) -> bool:
    return any(isinstance(item, dict) for item in x)

def _has_list(x) -> bool:
    return any(isinstance(item, list) for item in x)

def _has_nested(x) -> bool:
    return _has_dict(x) or _has_list(x)


def snap(search: Any, spec: Any, logger: logging.Logger) -> bool:
    
    if isinstance(spec, dict):
        if not isinstance(search, dict):
            logger.debug(f"type mismatch: search is {type(search)}, spec is dict")
            return False
        
        for key, value in spec.items():
            if key not in search:
                logger.debug(f"key '{key}' not found in search")
                return False
            if not snap(search[key], value, logger):
                return False

    elif isinstance(spec, list):
        if not isinstance(search, list):
            logger.debug(f"type mismatch: search is {type(search)}, spec is list")
            return False
        
        # every item in spec must match at least one item in search
        for spec_item in spec:
            if not any(snap(search_item, spec_item, logger) for search_item in search):
                logger.debug(f"no match found in search for spec item: {spec_item}")
                return False

    else:
        # leaf value — must match exactly
        if search != spec:
            logger.debug(f"value mismatch: search={search}, spec={spec}")
            return False

    return True
            
                
            
        
            
            

    return True

# %%
basic_logger = logging.getLogger(__name__)
basic_logger.addHandler(logging.StreamHandler())  # add this
snap(_search, _spec, basic_logger)
# Out:
# False

# %%
snap(_search_match, _spec, basic_logger)
# Out:
# True
