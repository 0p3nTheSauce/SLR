# %% [markdown]
# # Statistics for WLASL: Pre-processed

# %%
import json
from pathlib import Path
from typing import cast, List, TypedDict, Dict, Tuple
import matplotlib.pyplot as plt
import numpy as np
#locals
from configs import WLASL_ROOT, SPLIT_DIR, CLASSES_PATH
from video_dataset import get_wlasl_info
import stats
import preprocess as preproc
from statistics import median, mean, median_high, median_low
import pandas as pd      # not imported previously, so do it here
from IPython.display import display

# %% [markdown]
# # TODO:
# - make a flag to control preprocessed vs unprocessed
# - add removed instances
# - add bounding box info

# %% [markdown]
# ## Split

# %% [markdown]
# #### Pick split

# %%
split_options: List[stats.AVAIL_SPLITS] = ["asl100", "asl300", "asl1000", "asl2000"]
print('Options:')
for i, split_name in enumerate(split_options):
    print(f'{i} : {split_name}')
# Out:
# Options:
# 0 : asl100
# 1 : asl300
# 2 : asl1000
# 3 : asl2000

# %% [markdown]
# doing this for SAICIST because those experiments kept bad frame range labeled images

# %%
# labels_dir = Path('./preprocessed/labels_new')
labels_dir = Path('./preprocessed/labels_old_nobbox') 

with open(CLASSES_PATH, 'r') as f:
    classes = json.load(f)

# %% [markdown]
# ## Preprocessed
#
# Removed due to limited number of frames (cutoff 9):
#
# Split :  Videos
# asl1000 : 18223, 59958
# asl2000 : 18223, 59958, 15144
#
# if frame start or frame end were labeled wrong, they were set to 0 or frame length

# %%
def get_min_max_num_instances(per_instance_stats: Dict[str, stats.instance_stats]) -> Tuple[int, int]:
    """Returns the minumum and maximum number of instances in a dictionary of instance stats

    Args:
        per_instance_stats (Dict[str, stats.instance_stats]): A dictionary with stats for each class indexed by label_name

    Returns:
        Tuple[int, int]: min, max number of instances.
    """
    mini = float('inf')
    maxi = float(0)
    for inst_stats in per_instance_stats.values():
        num_inst = inst_stats['num_instances']
        if num_inst > maxi:
            maxi = num_inst
        if num_inst < mini:
            mini = num_inst
    return int(mini), int(maxi)

# %%
def get_min_max_num_signers(per_instance_stats: Dict[str, stats.instance_stats]) -> Tuple[int, int]:
    """Returns the minumum and maximum number of signers in a dictionary of instance stats

    Args:
        per_instance_stats (Dict[str, stats.instance_stats]): A dictionary with stats for each class indexed by label_name

    Returns:
        Tuple[int, int]: min, max number of signers.
    """
    mini = float('inf')
    maxi = float(0)
    for inst_stats in per_instance_stats.values():
        num_signers = len(inst_stats['signers_distribution'])
        if num_signers > maxi:
            maxi = num_signers
        if num_signers < mini:
            mini = num_signers
    return int(mini), int(maxi)

# %%
def create_instances_table(per_set_stats: Dict[stats.AVAIL_SETS, stats.set_stats]) -> pd.DataFrame:
    rows = []
    for set_name, set_stats in per_set_stats.items():
        mini_i, maxi_i = get_min_max_num_instances(set_stats['per_instance_stats'])
        mini_s, maxi_s = get_min_max_num_signers(set_stats['per_instance_stats'])
        rows.append({
            'Set name': set_name,
            'Num instances': set_stats['num_instances'],
            'Num signers': set_stats['num_signers'],
            'instances per gloss': f'[{mini_i} - {maxi_i}]',
            'signers per gloss': f'[{mini_s} - {maxi_s}]'
        })

    return pd.DataFrame(rows)

# %%
all_splits = {split : {} for split in split_options}

for split_name in split_options:
    split_dir = labels_dir / split_name
    set_info = stats.retrieve_split_data(split=split_name, labels_dir=labels_dir, pattern='*_instances*.json')
    seperated = {}
    set_keys = ['train', 'test', 'val']
    print(f'Split info for {split_name}')
    for  key, value in set_info.items():
        preproc_set = cast(List[preproc.InstanceDict], value)
        for set_key in set_keys:
            if key.startswith(set_key):
                seperated[set_key] = preproc_set
                break
    
    sep_wlasl_order = {}
    for key, value in seperated.items():
        sep_wlasl_order[key] = stats.reverse_preproc_format(value, classes=classes)

    
    per_set_stats = {}
    for set_name, glosses_subset in sep_wlasl_order.items():
        per_set_stats[set_name] = stats.get_set_stats(glosses_subset)

    all_splits[split_name] = per_set_stats
    
    display(create_instances_table(per_set_stats))
    print('\n', '-'*10)
# Out:
# Split info for asl100
#   Set name  Num instances  Num signers instances per gloss signers per gloss
# 0      val            338           69             [3 - 6]           [2 - 6]
# 1    train           1442           91           [12 - 30]          [7 - 15]
# 2     test            258           56             [2 - 5]           [2 - 4]
#  ----------
# Split info for asl300
#   Set name  Num instances  Num signers instances per gloss signers per gloss
# 0      val            901           88             [2 - 6]           [2 - 6]
# 1    train           3549          104            [9 - 30]          [5 - 15]
# 2     test            668           74             [2 - 5]           [1 - 4]
#  ----------
# Split info for asl1000
#   Set name  Num instances  Num signers instances per gloss signers per gloss
# 0      val           2319          101             [1 - 6]           [1 - 6]
# 1    train           8977          113            [6 - 30]          [4 - 15]
# 2     test           1876           89             [1 - 5]           [1 - 4]
#  ----------
# Split info for asl2000
#   Set name  Num instances  Num signers instances per gloss signers per gloss
# 0      val           3917          109             [1 - 6]           [1 - 6]
# 1    train          14290          117            [1 - 30]          [1 - 15]
# 2     test           2879          105             [1 - 5]           [1 - 4]
#  ----------

# %%
def get_numinstances_distribution(set_statistics: stats.set_stats):
    return stats.HistoGram(
        {gloss : instance['num_instances'] for gloss, instance in set_statistics['per_instance_stats'].items()}
    )

# %%
split_name: stats.AVAIL_SPLITS = 'asl2000'
num_classes = split_name[3:]
set_name: stats.AVAIL_SETS = 'test'
per_set_stats = all_splits[split_name]

# %%
num_classes = int(split_name[3:])
print(num_classes)
# Out:
# 2000

# %%
num_inst_dist = get_numinstances_distribution(per_set_stats['train']) #want the training distribution

stats.plot_distribution(num_inst_dist, set_name=set_name, split_name=split_name, metric='Number of Instances', categorical=True, figsize=(16, 4))
# Out:
# /home/luke/Code/SLR/code/stats.py:471: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from typing import Dict, Optional, Union, Any

def plot_instances_vs_f1(
    instance_counts: Dict[str, int],
    cls_report: Dict[str, Dict[str, float]],
    class_to_idx: Dict[str, int],
    save_path: Optional[Union[str, Path]] = None,
) -> None:
    """Plot correlation between number of training instances per gloss and per-class F1 score.

    Args:
        instance_counts: Dict mapping gloss name -> instance count.
        cls_report: Classification report dict from sklearn (output of test_topk_clsrep).
        class_to_idx: Dict mapping gloss name -> numeric class index.
        save_path: Optionally save the figure. Defaults to None.
    """
    counts = []
    f1_scores = []
    labels = []

    for gloss, count in instance_counts.items():
        idx = class_to_idx.get(gloss)
        if idx is None:
            continue
        report_entry = cls_report.get(str(idx))
        if report_entry is None:
            continue
        counts.append(count)
        f1_scores.append(report_entry["f1-score"])
        labels.append(gloss)

    counts = np.array(counts)
    f1_scores = np.array(f1_scores)

    # Pearson correlation + regression line
    # r, p = stats.pearsonr(counts, f1_scores)
    
    # With Kendall:
    tau, p = stats.kendalltau(counts, f1_scores)
    
    slope, intercept, *_ = stats.linregress(counts, f1_scores)
    x_line = np.linspace(counts.min(), counts.max(), 200)
    y_line = slope * x_line + intercept

    fig, ax = plt.subplots(figsize=(9, 6))

    ax.scatter(counts, f1_scores, alpha=0.6, edgecolors="white", linewidths=0.4,
               s=60, color="#4C72B0", zorder=3)
    # ax.plot(x_line, y_line, color="#DD4444", linewidth=1.5,
    #         label=f"Linear fit  (r = {r:.3f}, p = {p:.3e})")
    ax.plot(x_line, y_line, color="#DD4444", linewidth=1.5,
            label=f"Linear fit (Kendall $\\tau$ = {tau:.3f}, p = {p:.3e})")
    ax.set_xlabel("Number of instances", fontsize=12)
    ax.set_ylabel("F1 score", fontsize=12)
    ax.set_title("Per-gloss instance count vs. recognition F1 score", fontsize=13)
    ax.legend(fontsize=10)
    ax.grid(True, linestyle="--", alpha=0.4)

    plt.tight_layout()
    if save_path is not None:
        fig.savefig(save_path, dpi=150)
    plt.show()

# %%
def sort_dict(dict: Dict[str, Any]) -> Dict[str, Any]:
    return {key : value for key, value in sorted(dict.items(), key=lambda x: x[0])}

# %%
exps_dict_path = Path('./results/wlasl_saicist.json')
with open(exps_dict_path, 'r') as f:
    exps_dict = json.load(f)
exps_dict = cast(Dict[str, Dict[str, List[str]]], exps_dict)



for key, value in exps_dict.items():
    exps_dict[key] = sort_dict(value)

# %%
model_name = 'MViTv2_S'

# %%
print(exps_dict[split_name][model_name])
# Out:
# ['000']

# %%
import torch
runs_dir = Path('./runs') / split_name
checkpoint_path = runs_dir / f'{model_name}_exp{exps_dict[split_name][model_name][0]}' / 'checkpoints' / 'best.pth'
checkpoint = torch.load(checkpoint_path)
# Out:
# /tmp/ipykernel_3172160/542821056.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)

# %%
print(checkpoint.keys())
# Out:
# odict_keys(['backbone.0.weight', 'backbone.0.bias', 'backbone.1.class_token', 'backbone.2.0.norm1.weight', 'backbone.2.0.norm1.bias', 'backbone.2.0.norm2.weight', 'backbone.2.0.norm2.bias', 'backbone.2.0.attn.rel_pos_h', 'backbone.2.0.attn.rel_pos_w', 'backbone.2.0.attn.rel_pos_t', 'backbone.2.0.attn.qkv.weight', 'backbone.2.0.attn.qkv.bias', 'backbone.2.0.attn.project.0.weight', 'backbone.2.0.attn.project.0.bias', 'backbone.2.0.attn.pool_q.pool.weight', 'backbone.2.0.attn.pool_q.norm_act.0.weight', 'backbone.2.0.attn.pool_q.norm_act.0.bias', 'backbone.2.0.attn.pool_k.pool.weight', 'backbone.2.0.attn.pool_k.norm_act.0.weight', 'backbone.2.0.attn.pool_k.norm_act.0.bias', 'backbone.2.0.attn.pool_v.pool.weight', 'backbone.2.0.attn.pool_v.norm_act.0.weight', 'backbone.2.0.attn.pool_v.norm_act.0.bias', 'backbone.2.0.mlp.0.weight', 'backbone.2.0.mlp.0.bias', 'backbone.2.0.mlp.3.weight', 'backbone.2.0.mlp.3.bias', 'backbone.2.1.norm1.weight', 'backbone.2.1.norm1.bias', 'backbone.2.1.norm2.weight', 'backbone.2.1.norm2.bias', 'backbone.2.1.attn.rel_pos_h', 'backbone.2.1.attn.rel_pos_w', 'backbone.2.1.attn.rel_pos_t', 'backbone.2.1.attn.qkv.weight', 'backbone.2.1.attn.qkv.bias', 'backbone.2.1.attn.project.0.weight', 'backbone.2.1.attn.project.0.bias', 'backbone.2.1.attn.pool_q.pool.weight', 'backbone.2.1.attn.pool_q.norm_act.0.weight', 'backbone.2.1.attn.pool_q.norm_act.0.bias', 'backbone.2.1.attn.pool_k.pool.weight', 'backbone.2.1.attn.pool_k.norm_act.0.weight', 'backbone.2.1.attn.pool_k.norm_act.0.bias', 'backbone.2.1.attn.pool_v.pool.weight', 'backbone.2.1.attn.pool_v.norm_act.0.weight', 'backbone.2.1.attn.pool_v.norm_act.0.bias', 'backbone.2.1.mlp.0.weight', 'backbone.2.1.mlp.0.bias', 'backbone.2.1.mlp.3.weight', 'backbone.2.1.mlp.3.bias', 'backbone.2.1.project.weight', 'backbone.2.1.project.bias', 'backbone.2.2.norm1.weight', 'backbone.2.2.norm1.bias', 'backbone.2.2.norm2.weight', 'backbone.2.2.norm2.bias', 'backbone.2.2.attn.rel_pos_h', 'backbone.2.2.attn.rel_pos_w', 'backbone.2.2.attn.rel_pos_t', 'backbone.2.2.attn.qkv.weight', 'backbone.2.2.attn.qkv.bias', 'backbone.2.2.attn.project.0.weight', 'backbone.2.2.attn.project.0.bias', 'backbone.2.2.attn.pool_q.pool.weight', 'backbone.2.2.attn.pool_q.norm_act.0.weight', 'backbone.2.2.attn.pool_q.norm_act.0.bias', 'backbone.2.2.attn.pool_k.pool.weight', 'backbone.2.2.attn.pool_k.norm_act.0.weight', 'backbone.2.2.attn.pool_k.norm_act.0.bias', 'backbone.2.2.attn.pool_v.pool.weight', 'backbone.2.2.attn.pool_v.norm_act.0.weight', 'backbone.2.2.attn.pool_v.norm_act.0.bias', 'backbone.2.2.mlp.0.weight', 'backbone.2.2.mlp.0.bias', 'backbone.2.2.mlp.3.weight', 'backbone.2.2.mlp.3.bias', 'backbone.2.3.norm1.weight', 'backbone.2.3.norm1.bias', 'backbone.2.3.norm2.weight', 'backbone.2.3.norm2.bias', 'backbone.2.3.attn.rel_pos_h', 'backbone.2.3.attn.rel_pos_w', 'backbone.2.3.attn.rel_pos_t', 'backbone.2.3.attn.qkv.weight', 'backbone.2.3.attn.qkv.bias', 'backbone.2.3.attn.project.0.weight', 'backbone.2.3.attn.project.0.bias', 'backbone.2.3.attn.pool_q.pool.weight', 'backbone.2.3.attn.pool_q.norm_act.0.weight', 'backbone.2.3.attn.pool_q.norm_act.0.bias', 'backbone.2.3.attn.pool_k.pool.weight', 'backbone.2.3.attn.pool_k.norm_act.0.weight', 'backbone.2.3.attn.pool_k.norm_act.0.bias', 'backbone.2.3.attn.pool_v.pool.weight', 'backbone.2.3.attn.pool_v.norm_act.0.weight', 'backbone.2.3.attn.pool_v.norm_act.0.bias', 'backbone.2.3.mlp.0.weight', 'backbone.2.3.mlp.0.bias', 'backbone.2.3.mlp.3.weight', 'backbone.2.3.mlp.3.bias', 'backbone.2.3.project.weight', 'backbone.2.3.project.bias', 'backbone.2.4.norm1.weight', 'backbone.2.4.norm1.bias', 'backbone.2.4.norm2.weight', 'backbone.2.4.norm2.bias', 'backbone.2.4.attn.rel_pos_h', 'backbone.2.4.attn.rel_pos_w', 'backbone.2.4.attn.rel_pos_t', 'backbone.2.4.attn.qkv.weight', 'backbone.2.4.attn.qkv.bias', 'backbone.2.4.attn.project.0.weight', 'backbone.2.4.attn.project.0.bias', 'backbone.2.4.attn.pool_q.pool.weight', 'backbone.2.4.attn.pool_q.norm_act.0.weight', 'ba ...

# %%
from models import get_model

MViT = get_model(model_name, num_classes, 0.5)
# Out:
# /home/luke/miniconda3/envs/wlasl/lib/python3.10/site-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(

# %%
MViT.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %%
from models import norm_vals
from testing import setup_data
dloader, num_classes, m_permt, m_sh_et = setup_data(
		set_name='test',
		norm_dict=norm_vals(model_name),
		split=split_name,
		frame_size=224,
		num_frames=16,
		shuffle=False,
	)

# %%
from testing import test_topk_clsrep

topk_res, cls_report, all_targets, all_preds = test_topk_clsrep(
		model=MViT,
		test_loader=dloader,
		verbose=False,
	)
# Out:
# Testing:   0%|          | 0/2879 [00:00<?, ?it/s]
# Testing: 100%|██████████| 2879/2879 [02:30<00:00, 19.09it/s]
# top-k average per class acc: 0.355025, 0.69265, 0.7828999999999999
# top-k per instance acc: 0.38867662382771795, 0.7162209100382078, 0.7981938172976728
# Averag Loss: 2.92

# %%
from configs import CLASSES_PATH
import json

with open(CLASSES_PATH, 'r') as f:
    classes = json.load(f)
    
clss_to_idx = {gloss: idx for idx, gloss in enumerate(classes)}

plot_instances_vs_f1(num_inst_dist, cls_report, clss_to_idx, save_path=f'results/corr_mat_{model_name}.pdf')

# %%
from scipy import stats
from typing import Dict, Optional, Union, Any

def plot_signers_vs_f1(
    set_statistics: dict,
    cls_report: Dict[str, Dict[str, float]],
    class_to_idx: Dict[str, int],
    save_path: Optional[Union[str, Any]] = None,
) -> None:
    """Plot correlation between number of unique training signers per gloss and per-class F1 score."""
    
    # 1. Extract the number of unique signers per gloss
    # set_statistics['per_instance_stats'] contains 'signers_distribution' list
    signer_counts = {
        gloss: len(instance['signers_distribution']) 
        for gloss, instance in set_statistics['per_instance_stats'].items()
    }
    
    counts = []
    f1_scores = []
    labels = []

    # 2. Match counts with F1 scores using class_to_idx
    for gloss, count in signer_counts.items():
        idx = class_to_idx.get(gloss)
        if idx is None:
            continue
        report_entry = cls_report.get(str(idx))
        if report_entry is None:
            continue
        counts.append(count)
        f1_scores.append(report_entry["f1-score"])
        labels.append(gloss)

    counts = np.array(counts)
    f1_scores = np.array(f1_scores)

    # 3. Calculate Kendall's Tau and Linear Regression
    tau, p_val = stats.kendalltau(counts, f1_scores)
    slope, intercept, *_ = stats.linregress(counts, f1_scores)
    x_line = np.linspace(counts.min(), counts.max(), 200)
    y_line = slope * x_line + intercept

    # 4. Plotting
    fig, ax = plt.subplots(figsize=(9, 6))

    ax.scatter(counts, f1_scores, alpha=0.6, edgecolors="white", linewidths=0.4,
               s=60, color="#55A868", zorder=3) # Green color for signers
    ax.plot(x_line, y_line, color="#DD4444", linewidth=1.5,
            label=f"Linear fit (Kendall $\\tau$ = {tau:.3f}, p = {p_val:.3e})")

    ax.set_xlabel("Number of Unique Signers", fontsize=12)
    ax.set_ylabel("F1 score", fontsize=12)
    ax.set_title("Per-gloss Signer Count vs. Recognition F1 Score", fontsize=13)
    ax.legend(fontsize=10)
    ax.grid(True, linestyle="--", alpha=0.4)

    plt.tight_layout()
    if save_path is not None:
        fig.savefig(save_path, dpi=150)
    plt.show()
    
    print(f"Kendall's tau: {tau:.4f}")
    print(f"p-value: {p_val:.4e}")

# --- How to call the function ---
# Pass the 'train' split stats directly, along with your existing variables
plot_signers_vs_f1(
    set_statistics=per_set_stats['train'], 
    cls_report=cls_report, 
    class_to_idx=clss_to_idx, 
    save_path=f'results/corr_signers_{model_name}.pdf'
)
# Out:
# Kendall's tau: 0.2657
# p-value: 1.7176e-47

# %%
def plot_variation_vs_f1(
    set_statistics: dict,
    cls_report: Dict[str, Dict[str, float]],
    class_to_idx: Dict[str, int],
    save_path: Optional[Union[str, Any]] = None,
) -> None:
    """Plot correlation between number of unique training variations per gloss and per-class F1 score."""
    
    # 1. Extract the number of unique signers per gloss
    # set_statistics['per_instance_stats'] contains 'signers_distribution' list
    signer_counts = {
        gloss: len(instance['variation_distribution']) 
        for gloss, instance in set_statistics['per_instance_stats'].items()
    }
    
    counts = []
    f1_scores = []
    labels = []

    # 2. Match counts with F1 scores using class_to_idx
    for gloss, count in signer_counts.items():
        idx = class_to_idx.get(gloss)
        if idx is None:
            continue
        report_entry = cls_report.get(str(idx))
        if report_entry is None:
            continue
        counts.append(count)
        f1_scores.append(report_entry["f1-score"])
        labels.append(gloss)

    counts = np.array(counts)
    f1_scores = np.array(f1_scores)

    # 3. Calculate Kendall's Tau and Linear Regression
    tau, p_val = stats.kendalltau(counts, f1_scores)
    slope, intercept, *_ = stats.linregress(counts, f1_scores)
    x_line = np.linspace(counts.min(), counts.max(), 200)
    y_line = slope * x_line + intercept

    # 4. Plotting
    fig, ax = plt.subplots(figsize=(9, 6))

    ax.scatter(counts, f1_scores, alpha=0.6, edgecolors="white", linewidths=0.4,
               s=60, color="#55A868", zorder=3) # Green color for signers
    ax.plot(x_line, y_line, color="#DD4444", linewidth=1.5,
            label=f"Linear fit (Kendall $\\tau$ = {tau:.3f}, p = {p_val:.3e})")

    ax.set_xlabel("Number of Unique variations", fontsize=12)
    ax.set_ylabel("F1 score", fontsize=12)
    ax.set_title("Per-gloss Variation count vs. Recognition F1 Score", fontsize=13)
    ax.legend(fontsize=10)
    ax.grid(True, linestyle="--", alpha=0.4)

    plt.tight_layout()
    if save_path is not None:
        fig.savefig(save_path, dpi=150)
    plt.show()
    
    print(f"Kendall's tau: {tau:.4f}")
    print(f"p-value: {p_val:.4e}")

# --- How to call the function ---
# Pass the 'train' split stats directly, along with your existing variables
plot_variation_vs_f1(
    set_statistics=per_set_stats['train'], 
    cls_report=cls_report, 
    class_to_idx=clss_to_idx, 
    save_path=f'results/corr_signers_{model_name}.pdf'
)
# Out:
# Kendall's tau: 0.0073
# p-value: 7.2409e-01

# %%
def unpack(hist: Dict):
    unpacked = []
    for length, count in hist.items():
        unpacked.extend([length]*count)
    return unpacked

# %%
def plot_length_vs_f1(
    set_statistics: dict,
    cls_report: Dict[str, Dict[str, float]],
    class_to_idx: Dict[str, int],
    save_path: Optional[Union[str, Any]] = None,
) -> None:
    """Plot correlation between number of unique training variations per gloss and per-class F1 score."""
    
    # 1. Extract the number of unique signers per gloss
    # set_statistics['per_instance_stats'] contains 'signers_distribution' list
    signer_counts = {
        gloss: np.median(unpack(instance['length_distribution']))
        for gloss, instance in set_statistics['per_instance_stats'].items()
    }
    
    counts = []
    f1_scores = []
    labels = []

    # 2. Match counts with F1 scores using class_to_idx
    for gloss, count in signer_counts.items():
        idx = class_to_idx.get(gloss)
        if idx is None:
            continue
        report_entry = cls_report.get(str(idx))
        if report_entry is None:
            continue
        counts.append(count)
        f1_scores.append(report_entry["f1-score"])
        labels.append(gloss)

    counts = np.array(counts)
    f1_scores = np.array(f1_scores)

    # 3. Calculate Kendall's Tau and Linear Regression
    tau, p_val = stats.kendalltau(counts, f1_scores)
    slope, intercept, *_ = stats.linregress(counts, f1_scores)
    x_line = np.linspace(counts.min(), counts.max(), 200)
    y_line = slope * x_line + intercept

    # 4. Plotting
    fig, ax = plt.subplots(figsize=(9, 6))

    ax.scatter(counts, f1_scores, alpha=0.6, edgecolors="white", linewidths=0.4,
               s=60, color="#55A868", zorder=3) # Green color for signers
    ax.plot(x_line, y_line, color="#DD4444", linewidth=1.5,
            label=f"Linear fit (Kendall $\\tau$ = {tau:.3f}, p = {p_val:.3e})")

    ax.set_xlabel("Median length frames", fontsize=12)
    ax.set_ylabel("F1 score", fontsize=12)
    ax.set_title("Per-gloss Median length vs. Recognition F1 Score", fontsize=13)
    ax.legend(fontsize=10)
    ax.grid(True, linestyle="--", alpha=0.4)

    plt.tight_layout()
    if save_path is not None:
        fig.savefig(save_path, dpi=150)
    plt.show()
    
    print(f"Kendall's tau: {tau:.4f}")
    print(f"p-value: {p_val:.4e}")

# --- How to call the function ---
# Pass the 'train' split stats directly, along with your existing variables
plot_length_vs_f1(
    set_statistics=per_set_stats['train'], 
    cls_report=cls_report, 
    class_to_idx=clss_to_idx, 
    save_path=f'results/corr_signers_{model_name}.pdf'
)
# Out:
# Kendall's tau: 0.0623
# p-value: 2.5364e-04

# %%
from scipy import stats
from typing import Dict, Optional, Union, Any

def plot_combined_richness_vs_f1(
    set_statistics: dict,
    cls_report: Dict[str, Dict[str, float]],
    class_to_idx: Dict[str, int],
    save_path: Optional[Union[str, Any]] = None,
) -> None:
    """Plot correlation between a combined Data Richness Index (Instances * Signers) and F1 score."""
    
    # 1. Extract Instances and Signers, then combine them
    richness_scores = {}
    for gloss, instance in set_statistics['per_instance_stats'].items():
        num_instances = instance['num_instances']
        num_signers = len(instance['signers_distribution'])
        # Combined Metric: Instances * Signers
        richness_scores[gloss] = num_instances * num_signers
    
    scores = []
    f1_scores = []
    labels = []

    # 2. Match combined scores with F1 scores
    for gloss, score in richness_scores.items():
        idx = class_to_idx.get(gloss)
        if idx is None:
            continue
        report_entry = cls_report.get(str(idx))
        if report_entry is None:
            continue
        scores.append(score)
        f1_scores.append(report_entry["f1-score"])
        labels.append(gloss)

    scores = np.array(scores)
    f1_scores = np.array(f1_scores)

    # 3. Calculate Kendall's Tau and Linear Regression
    tau, p_val = stats.kendalltau(scores, f1_scores)
    slope, intercept, *_ = stats.linregress(scores, f1_scores)
    x_line = np.linspace(scores.min(), scores.max(), 200)
    y_line = slope * x_line + intercept

    # 4. Plotting
    fig, ax = plt.subplots(figsize=(9, 6))

    ax.scatter(scores, f1_scores, alpha=0.6, edgecolors="white", linewidths=0.4,
               s=60, color="#9B59B6", zorder=3) # Purple color for the combined metric
    ax.plot(x_line, y_line, color="#DD4444", linewidth=1.5,
            label=f"Linear fit (Kendall $\\tau$ = {tau:.3f}, p = {p_val:.3e})")

    ax.set_xlabel("Data Richness Index (Instances × Signers)", fontsize=12)
    ax.set_ylabel("F1 score", fontsize=12)
    ax.set_title("Combined Data Richness vs. Recognition F1 Score", fontsize=13)
    ax.legend(fontsize=10)
    ax.grid(True, linestyle="--", alpha=0.4)

    plt.tight_layout()
    if save_path is not None:
        fig.savefig(save_path, dpi=150)
    plt.show()
    
    print(f"Kendall's tau (Combined Metric): {tau:.4f}")
    print(f"p-value: {p_val:.4e}")

# --- How to call the function ---
plot_combined_richness_vs_f1(
    set_statistics=per_set_stats['train'], 
    cls_report=cls_report, 
    class_to_idx=clss_to_idx, 
    save_path=f'results/corr_richness_{model_name}.pdf'
)
# Out:
# Kendall's tau (Combined Metric): 0.2556
# p-value: 3.4028e-46

# %%
import pandas as pd
from typing import Dict

def get_performance_outliers(
    set_statistics: dict,
    cls_report: Dict[str, Dict[str, float]],
    class_to_idx: Dict[str, int],
    low_signer_thresh: int = 3,
    high_f1_thresh: float = 0.80,
    high_signer_thresh: int = 10,
    low_f1_thresh: float = 0.20
):
    """Extracts and prints overachieving and underachieving glosses."""
    
    data = []
    
    # 1. Compile all data into a single list of dictionaries
    for gloss, instance in set_statistics['per_instance_stats'].items():
        idx = class_to_idx.get(gloss)
        if idx is None:
            continue
            
        report_entry = cls_report.get(str(idx))
        if report_entry is None:
            continue
            
        num_instances = instance['num_instances']
        num_signers = len(instance['signers_distribution'])
        f1_score = report_entry["f1-score"]
        
        data.append({
            "Gloss": gloss,
            "Instances": num_instances,
            "Signers": num_signers,
            "F1_Score": f1_score
        })
        
    df = pd.DataFrame(data)
    
    # 2. Filter for Overachievers (Low data, High F1)
    overachievers = df[
        (df['Signers'] <= low_signer_thresh) & 
        (df['F1_Score'] >= high_f1_thresh)
    ].sort_values(by=['F1_Score', 'Signers'], ascending=[False, True])
    
    # 3. Filter for Underachievers (High data, Low F1)
    underachievers = df[
        (df['Signers'] >= high_signer_thresh) & 
        (df['F1_Score'] <= low_f1_thresh)
    ].sort_values(by=['F1_Score', 'Signers'], ascending=[True, False])
    
    # 4. Print the results nicely
    print("🏆 THE OVERACHIEVERS 🏆")
    print(f"Glosses with <= {low_signer_thresh} signers but F1 >= {high_f1_thresh}")
    print("-" * 50)
    if overachievers.empty:
        print("No glosses met this criteria. (You may need to adjust the thresholds).")
    else:
        print(overachievers.to_string(index=False))
        
    print("\n\n" + "="*50 + "\n")
    
    print("📉 THE UNDERACHIEVERS 📉")
    print(f"Glosses with >= {high_signer_thresh} signers but F1 <= {low_f1_thresh}")
    print("-" * 50)
    if underachievers.empty:
        print("No glosses met this criteria. (You may need to adjust the thresholds).")
    else:
        print(underachievers.to_string(index=False))

    return overachievers, underachievers

# --- How to call the function ---
# Pass the 'train' split stats to see what it learned from!
over_df, under_df = get_performance_outliers(
    set_statistics=per_set_stats['train'], 
    cls_report=cls_report, 
    class_to_idx=clss_to_idx,
    # You can tweak these thresholds if your lists are too long or too short:
    low_signer_thresh=3,   
    high_f1_thresh=0.80,   
    high_signer_thresh=6, 
    low_f1_thresh=0.20     
)
# Out:
# 🏆 THE OVERACHIEVERS 🏆
# Glosses with <= 3 signers but F1 >= 0.8
# --------------------------------------------------
#     Gloss  Instances  Signers  F1_Score
# beginning          5        3       1.0
#  swimsuit          5        3       1.0
#
#
# ==================================================
#
# 📉 THE UNDERACHIEVERS 📉
# Glosses with >= 6 signers but F1 <= 0.2
# --------------------------------------------------
#          Gloss  Instances  Signers  F1_Score
#         before         18       13       0.0
#           thin         15       13       0.0
#            eat         14       13       0.0
#         yellow         13       13       0.0
#            hot         15       12       0.0
#           what         14       12       0.0
#           blue         15       12       0.0
#        hearing         15       12       0.0
#           time         14       12       0.0
#          wrong         15       11       0.0
#           corn         13       11       0.0
#          short         13       11       0.0
#           need         13       11       0.0
#      different         12       11       0.0
#            red         12       11       0.0
#       bathroom         11       11       0.0
#           help         15       10       0.0
#        bowling         15       10       0.0
#          right         12       10       0.0
#          check         11       10       0.0
#           sick         12       10       0.0
#        blanket         11       10       0.0
#           call         11       10       0.0
#           copy         11       10       0.0
#          first         11       10       0.0
#        approve         10       10       0.0
#            new         10       10       0.0
#           east         10       10       0.0
#           give         13        9       0.0
#            but         12        9       0.0
#           show         12        9       0.0
#           take         11        9       0.0
#           cute         11        9       0.0
#            far         10        9       0.0
#           list         11        9       0.0
#        balance         10        9       0.0
#        careful         10        9       0.0
#          drive         10        9       0.0
#         future         10        9       0.0
#           hope         10        9       0.0
#        husband         10        9       0.0
#           mean         10        9       0.0
#          music         10        9       0.0
#         office         10        9       0.0
#     restaurant         10        9       0.0
#          small         10        9       0.0
#          south         10        9       0.0
#          catch         10        9       0.0
#           draw         10        9       0.0
#            egg         10        9       0.0
#    environment          9        9       0.0
#          heart         10        9       0.0
#           kill         10        9       0.0
#            not         10        9       0.0
#       scissors         10        9       0.0
#          throw          9        9       0.0
#           vote         10        9       0.0
#            box          9        9       0.0
#        chicken          9        9       0.0
#           deep          9        9       0.0
#            ear          9        9       0.0
#          floor          9        9       0.0
#         follow          9        9       0.0
#            get          9        9       0.0
#          hello          9        9       0.0
#          marry          9        9       0.0
#         monkey          9        9       0.0
#         people          9        9       0.0
#         pepper          9        9       0.0
#           rain          9        9       0.0
#           soap          9        9       0.0
#        weekend          9        9       0.0
#       backpack         11        8       0.0
#          leave         10        8       0.0
#            you         11        8       0.0
#       interest         10        8       0.0
#          party         10        8       0.0
#           ride         10        8       0.0
#          teach         10        8       0.0
#           back          9        8       0.0
#          crazy         10        8       0.0
#          nurse         10        8       0.0
#             ok         10        8       0.0
#          think         10        8       0.0
#            age          9        8       0.0
#          alone          9        8       0.0
#            cup          9        8       0.0
#        dentist          8        8       0.0
#          dirty          9        8       0.0
#       elephant          9        8       0.0
#        english          9        8       0.0
#         escape          9        8       0.0
#         happen          9        8       0.0
#        jealous          9        8       0.0
#           miss          9        8       0.0
#          phone          9        8       0.0
#           plus          9        8       0.0
#          point          9        8       0.0
#          stink          9        8       0.0
#          toast          8        8       0.0
#         toilet          9        8       0.0
#           town          9        8       0.0
#          after          8        8       0.0
#          allow          8        8       0.0
#          angel          8        8       0.0
#         answer          8        8       0.0
#            art          8        8       0.0
#          awful          8        8       0.0
#           beer          8        8       0.0
#          cheap          8        8       0.0
#          clean          8        8       0.0
#        contact          8        8       0.0
#         depend          8        8       0.0
#           desk          8        8       0.0
#     dictionary          8        8       0.0
#       elevator          8        8       0.0
#           food          8        8       0.0
#    grandfather          8        8       0.0
#          great          8        8       0.0
#          guess          8        8       0.0
#          lucky          8        8       0.0
#      microwave          8        8       0.0
#       postpone          8        8       0.0
#         reason          8        8       0.0
#       religion          8        8       0.0
#          sound          8        8       0.0
#        stomach          8        8       0.0
#          story          8        8       0.0
#         stress          8        8       0.0
#         summer          8        8       0.0
#         ticket          8        8       0.0
#        tuesday          8        8       0.0
#           weak          8        8       0.0
#           wind          8        8       0.0
#          pizza         13        7       0.0
#           same         12        7       0.0
#          trade         11        7       0.0
#           past         10        7       0.0
#           plan         10        7       0.0
#          delay         10        7       0.0
#           hard         10        7       0.0
#          bored          9        7       0.0
#           dive          8        7       0.0
#    investigate          9        7       0.0
#        kitchen          8        7       0.0
#           poor          9        7       0.0
#       sentence          9        7       0.0
#        surgery          9        7       0.0
#           bark          8        7       0.0
#            big          8        7       0.0
#         bitter          8        7       0.0
#     california          8        7       0.0
#         corner          8        7       0.0
#        correct          8        7       0.0
#         easter          8        7       0.0
#            end          8        7       0.0
#          event          8        7       0.0
#       exchange          8        7       0.0
#       neighbor          8        7       0.0
#        outside          8        7       0.0
#          peach          8        7       0.0
#        present          8        7       0.0
#         prison          8        7       0.0
#         really          8        7       0.0
#           sell          8        7       0.0
#        serious          8        7       0.0
#         single          8        7       0.0
#          smile          8        7       0.0
#           soft          8        7       0.0
#          spain          8        7       0.0
#          sugar          8        7       0.0
#        suspect          8        7       0.0
#          tease          8        7       0.0
#           that          8        7       0.0
#          until          8        7       0.0
#           will          8        7       0.0
#        analyze          7        7       0.0
#           body          7        7       0.0
#         cancel          7        7       0.0
#        destroy          7        7       0.0
#        diamond          7        7       0.0
#          eagle          7        7       0.0
#          early          7        7       0.0
#       exercise          7        7       0.0
#     experiment          7        7       0.0
#           fact          7        7       0.0
#         france          7        7       0.0
#           golf          7        7       0.0
#           gone          7        7       0.0
#    grandmother          7        7       0.0
#         grapes          7        7       0.0
#      hamburger          7        7       0.0
#           hate          7        7       0.0
#     impossible          7        7       0.0
#             in          7        7       0.0
#         listen          7        7       0.0
#          march          7        7       0.0
#       mechanic          7        7       0.0
#            mom          7        7       0.0
#         museum          7        7       0.0
#           must          7        7       0.0
#        nervous          7        7       0.0
#           nose          7        7       0.0
#        prepare          7        7       0.0
#         pretty          7        7       0.0
#        promise          7        7       0.0
#            put          7        7       0.0
#         skinny          7        7       0.0
#          skirt          7        7       0.0
#        special          7        7       0.0
#      translate          7        7       0.0
#      underwear          7        7       0.0
#           wood          7        7       0.0
#          actor          7        7       0.0
#          agree          7        7       0.0
#          alarm          7        7       0.0
#      apartment          7        7       0.0
#           away          7        7       0.0
#      beautiful          7        7       0.0
#         become          7        7       0.0
#          below          7        7       0.0
#            bet          7        7       0.0
#        bicycle          7        7       0.0
#        biology          7        7       0.0
#       building          7        7       0.0
#           busy          7        7       0.0
#           camp          7        7       0.0
#          chain          7        7       0.0
#         chance          7        7       0.0
#          chase          7        7       0.0
#          climb          7        7       0.0
#        command          7        7       0.0
#      community          7        7       0.0
#       complain          7        7       0.0
#     compromise          7        7       0.0
#     contribute          7        7       0.0
#           cost          7        7       0.0
#          couch          7        7       0.0
#        curious          7        7       0.0
#       describe          7        7       0.0
#       diarrhea          7        7       0.0
#       disagree          7        7       0.0
#         divide          7        7       0.0
#         double          7        7       0.0
#     earthquake          7        7       0.0
#          eight          7        7       0.0
#         energy          7        7       0.0
#       evidence          7        7       0.0
#         expect          7        7       0.0
#       favorite          7        7       0.0
#        finally          7        7       0.0
#        germany          7        7       0.0
#           goat          7        7       0.0
#           grow          7        7       0.0
#            gum          7        7       0.0
#          honor          7        7       0.0
#             if          7        7       0.0
#    information          7        7       0.0
#         invite          7        7       0.0
#           keep          7        7       0.0
#       keyboard          7        7       0.0
#           land          7        7       0.0
#         lawyer          7        7       0.0
#           loud          7        7       0.0
#          lousy          7        7       0.0
#       mountain          7        7       0.0
#          mouth          7        7       0.0
#           neck          7        7       0.0
#          ocean          7        7       0.0
#            owe          7        7       0.0
#         period          7        7       0.0
#        predict          7        7       0.0
#          print          7        7       0.0
#        printer          7        7       0.0
#        project          7        7       0.0
#        protect          7        7       0.0
#          prove          7        7       0.0
#        provide          7        7       0.0
#         punish          7        7       0.0
#          quick          7        7       0.0
#        rainbow          7        7       0.0
#         remove          7        7       0.0
#        revenge          7        7       0.0
#           rude          7        7       0.0
#            say          7        7       0.0
#         senate          7        7       0.0
#       separate          7        7       0.0
#            shy          7        7       0.0
#          socks          7        7       0.0
#          solid          7        7       0.0
#      sometimes          7        7       0.0
#         spider          7        7       0.0
#          stare          7        7       0.0
#          store          7        7       0.0
#          straw          7        7       0.0
#      structure          7        7       0.0
#        suggest          7        7       0.0
#           sure          7        7       0.0
#       surprise          7        7       0.0
#        sweater          7        7       0.0
#          taste          7        7       0.0
#    thermometer          7        7       0.0
#            tie          7        7       0.0
#          topic          7        7       0.0
#          touch          7        7       0.0
#     tournament          7        7       0.0
#            try          7        7       0.0
#       umbrella          7        7       0.0
#     vocabulary          7        7       0.0
#          waste          7        7       0.0
#        welcome          7        7       0.0
#           worm          7        7       0.0
#     wristwatch          7        7       0.0
#       yourself          7        7       0.0
#          crash         10        6       0.0
#        earring          7        6       0.0
#          japan          8        6       0.0
#          lemon          9        6       0.0
#         speech          8        6       0.0
#          price          8        6       0.0
#          spray          8        6       0.0
#        therapy          8        6       0.0
#          watch          8        6       0.0
#            add          7        6       0.0
#        attract          7        6       0.0
#         barely          7        6       0.0
#        benefit          7        6       0.0
#          blame          7        6       0.0
#         bother          7        6       0.0
#          cards          7        6       0.0
#         drawer          7        6       0.0
#          every          7        6       0.0
#       feedback          7        6       0.0
#           fold          7        6       0.0
#          funny          7        6       0.0
#          group          7        6       0.0
#         ignore          7        6       0.0
#        lecture          7        6       0.0
#        operate          7        6       0.0
#          other          7        6       0.0
#         pillow          7        6       0.0
#            rat          7        6       0.0
#         reject          7        6       0.0
#        require          7        6       0.0
#          rough          7        6       0.0
#            sky          7        6       0.0
#          staff          7        6       0.0
#     television          7        6       0.0
#       triangle          7        6       0.0
#         violin          7        6       0.0
#         across          7        6       0.0
#           best          7        6       0.0
#        caption          7        6       0.0
#        cracker          7        6       0.0
#       dissolve          7        6       0.0
#          fancy          7        6       0.0
#        herself          6        6       0.0
#       increase          7        6       0.0
#           open          7        6       0.0
#      overwhelm          7        6       0.0
#           pain          7        6       0.0
#        perfect          7        6       0.0
#   presentation          7        6       0.0
#        private          7        6       0.0
#  procrastinate          7        6       0.0
#        puzzled          7        6       0.0
#       rehearse          7        6       0.0
#           roof          7        6       0.0
#    screwdriver          7        6       0.0
#         second          7        6       0.0
#         shrimp          7        6       0.0
#           spin          6        6       0.0
#         stairs          7        6       0.0
#        suppose          7        6       0.0
#          their          7        6       0.0
#          thing          6        6       0.0
#       thousand          7        6       0.0
#          three          7        6       0.0
#            two          7        6       0.0
#           type          6        6       0.0
#          above          6        6       0.0
#     accomplish          6        6       0.0
#    anniversary          6        6       0.0
#        another          6        6       0.0
#    appropriate          6        6       0.0
#       behavior          6        6       0.0
#           bell          6        6       0.0
#          bless          6        6       0.0
#          blood          6        6       0.0
#          brave          6        6       0.0
#        breathe          6        6       0.0
#           bull          6        6       0.0
#      butterfly          6        6       0.0
#       catholic          6        6       0.0
#           cent          6        6       0.0
#      chemistry          6        6       0.0
#         cherry          6        6       0.0
#           chop          6        6       0.0
#      christian          6        6       0.0
#      cigarette          6        6       0.0
#         clever          6        6       0.0
#          clown          6        6       0.0
#           coat          6        6       0.0
#        control          6        6       0.0
#          count          6        6       0.0
#         defend          6        6       0.0
#         degree          6        6       0.0
#            die          6        6       0.0
#     disconnect          6        6       0.0
#       discover          6        6       0.0
#           drum          6        6       0.0
#    electrician          6        6       0.0
#        england          6        6       0.0
#         excuse          6        6       0.0
#     eyeglasses          6        6       0.0
#        faculty          6        6       0.0
#         famous          6        6       0.0
#            fix          6        6       0.0
#           fork          6        6       0.0
#           four          6        6       0.0
#      furniture          6        6       0.0
#      gallaudet          6        6       0.0
#          ghost          6        6       0.0
#          glass          6        6       0.0
#        gorilla          6        6       0.0
#           gray          6        6       0.0
#          guide          6        6       0.0
#          habit          6        6       0.0
#         health          6        6       0.0
#          heavy          6        6       0.0
#         helmet          6        6       0.0
#         honest          6        6       0.0
#            hug          6        6       0.0
#           hunt          6        6       0.0
#          image          6        6       0.0
#    interesting          6        6       0.0
#          italy          6        6       0.0
#         jewish          6        6       0.0
#          judge          6        6       0.0
#           leaf          6        6       0.0
#           lend          6        6       0.0
#    linguistics          6        6       0.0
#           long          6        6       0.0
#          magic          6        6       0.0
#     mainstream          6        6       0.0
#          major          6        6       0.0
#        manager          6        6       0.0
#        maximum          6        6       0.0
#         middle          6        6       0.0
#           mind          6        6       0.0
#       multiply          6        6       0.0
#        nothing          6        6       0.0
#            odd          6        6       0.0
#             on          6        6       0.0
#           only          6        6       0.0
#            out          6        6       0.0
#        percent          6        6       0.0
#          piano          6        6       0.0
#           pick          6        6       0.0
#         pocket          6        6       0.0
#       positive          6        6       0.0
#          proof          6        6       0.0
#        purpose          6        6       0.0
#      recognize          6        6       0.0
#   relationship          6        6       0.0
#         repeat          6        6       0.0
#        replace          6        6       0.0
#         report          6        6       0.0
#      represent          6        6       0.0
#        request          6        6       0.0
# responsibility          6        6       0.0
#           ring          6        6       0.0
#            rob          6        6       0.0
#           rock          6        6       0.0
#           role          6        6       0.0
#           rush          6        6       0.0
#         salute          6        6       0.0
#      sensitive          6        6       0.0
#          serve          6        6       0.0
#          seven          6        6       0.0
#        shampoo          6        6       0.0
#            she          6        6       0.0
#          shelf          6        6       0.0
#       shopping          6        6       0.0
#           sing          6        6       0.0
#            six          6        6       0.0
#       skeleton          6        6       0.0
#         sketch          6        6       0.0
#       specific          6        6       0.0
#          steel          6        6       0.0
#       subtract          6        6       0.0
#         suffer          6        6       0.0
#        surface          6        6       0.0
#          swing          6        6       0.0
#           tale          6        6       0.0
#          teeth          6        6       0.0
#       terrible          6        6       0.0
#           they          6        6       0.0
#        through          6        6       0.0
#          title          6        6       0.0
#          tooth          6        6       0.0
#     toothbrush          6        6       0.0
#      tradition          6        6       0.0
#         trophy          6        6       0.0
#           true          6        6       0.0
#          trust          6        6       0.0
#           verb          6        6       0.0
#           wall          6        6       0.0
#     watermelon          6        6       0.0
#            way          6        6       0.0
#          weird          6        6       0.0
#          while          6        6       0.0
#           wide          6        6       0.0
#        willing          6        6       0.0
#      wonderful          6        6       0.0

# %%
import json

# 1. Convert the DataFrames into lists of dictionaries
outliers_dict = {
    "overachievers": over_df.to_dict(orient="records"),
    "underachievers": under_df.to_dict(orient="records")
}

# 2. Save the dictionary to a JSON file
save_path = "performance_outliers.json"
with open(save_path, "w") as f:
    json.dump(outliers_dict, f, indent=4)

print(f"Successfully saved outliers to {save_path}")
# Out:
# Successfully saved outliers to performance_outliers.json
