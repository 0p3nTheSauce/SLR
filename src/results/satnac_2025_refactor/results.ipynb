# %% [markdown]
# # Filtering for runs similar to SATNAC 2025 comparison

# %%
# locals
import pandas as pd

# from src.configs import get_avail_splits
from src.results import fetch_runs
from src.run_types import CUTOFF_9_NAMES, RESULTS_DIR

# %%
results_dir = RESULTS_DIR / 'satnac_2025_refactor'
# runs = load_runs(results_dir / 'runs.json')
runs = fetch_runs(results_dir / 'filters.py', output_path='./runs.json')
print(f'{len(runs)} found')
# Out:
# 37 found

# %% [markdown]
# ## Now we can compare the runs

# %%
avail_acc_types = ["top_k_average_per_class_acc", "top_k_per_instance_acc"]
acc_type = avail_acc_types[1]
set_names = ['test', 'val']

# %% [markdown]
# #### Convert to DataFrame

# %%
df_format = [
    {
        "model": run.admin.model,
        "exp no": run.admin.exp_no,
        "run_id": run.wandb.run_id,
        "No. frames": run.data.target_length,
        "subset": run.admin.split,
    }
    | {f'{set_name} {k}': v for set_name in set_names for k, v in run.results.model_dump()[set_name][acc_type].items()}
    | {
        "best_val_acc": run.results.best_val_acc,
        "best_val_loss": run.results.best_val_loss,
        "test_loss": run.results.test.average_loss,
        "config path": run.admin.config_path,
        "weight path": run.admin.weight_path,
        }
    for run in runs
]


df = pd.DataFrame(df_format)

# %%
ns = [1, 5, 10] #topn
for set_name in set_names:
    for n in ns:
        old_name, new_name = f"{set_name} top{n}", f"{set_name.capitalize()} Top-{n}"

        df = df.rename(columns={old_name: new_name})
        df[new_name] = df[new_name].apply(lambda x: f"{x * 100:.2f}")

# df

# %%
# print(get_avail_splits())
subsets = CUTOFF_9_NAMES
# subsets = get_avail_splits()
for set_name in subsets:
    subdf = df[df['subset'] == set_name]
    print(f'{set_name}'.capitalize())
    # display(subdf.sort_values('Test Top-1', ascending=False))
    # display(subdf.sort_values('best_val_loss', ascending=True))
    display(subdf.sort_values('test_loss', ascending=True))
# Out:
# Asl100_cutoff_9
#          model exp no    run_id  No. frames           subset Test Top-1  \
# 32    MViTv2_S    007      None          16  asl100_cutoff_9      79.46
# 0     MViTv2_S    010      None          16  asl100_cutoff_9      73.26
# 25    MViTv1_B    003  j8v7g110          16  asl100_cutoff_9      71.32
# 28    Swin3D_T    003  kqbvbgsr          16  asl100_cutoff_9      60.08
# 26    Swin3D_B    003  wo8fe3st          16  asl100_cutoff_9      54.26
# 31      R3D_18    006  56o6x69m          16  asl100_cutoff_9      55.04
# 36         S3D    023  yaylbndm          32  asl100_cutoff_9      58.14
# 1     Swin3D_S    008  aa5dvclt          32  asl100_cutoff_9      63.18
# 27    Swin3D_S    003  0znkyo6w          16  asl100_cutoff_9      66.67
# 29         S3D    046  5xgru0cs          16  asl100_cutoff_9      50.39
# 3          S3D    051  f6r2dos3          16  asl100_cutoff_9      53.10
# 30  R(2+1)D_18    007  v33pxh3s          16  asl100_cutoff_9      48.06
#
#    Test Top-5 Test Top-10 Val Top-1 Val Top-5 Val Top-10  best_val_acc  \
# 32      91.86       95.35     75.15     93.49      95.56     78.106509
# 0       91.47       94.57     73.96     93.20      97.04     77.218935
# 25      89.53       91.86     68.64     92.01      96.45     73.668639
# 28      85.27       93.80     61.24     89.05      94.67     71.597633
# 26      82.56       91.09     58.88     86.98      93.20     68.934911
# 31      82.17       88.76     65.68     86.09      91.42     68.639053
# 36      86.43       92.64     65.09     88.46      94.38     71.301775
# 1       86.05       93.41     73.37     92.90      95.86     75.147929
# 27      87.21       91.86     67.75     89.35      93.20     71.301775
# 29      77.91       86.43     55.92     84.02      88.76     62.130178
# 3       79.84       87.98     53.10     79.84      87.98     61.538462
# 30      77.13       86.05     55.03     80.18      87.28     59.171598
#
#     best_val_loss  test_loss  \
# 32       0.964134   0.956202
# 0        0.920471   1.066370
# 25       1.178978   1.287940
# 28       1.471827   1.701947
# 26       1.489241   1.755205
# 31       1.445135   1.782112
# 36       1.447925   1.801966
# 1        1.228877   1.809145
# 27       1.567957   1.822755
# 29       1.803888   2.053737
# 3        1.839390   2.236297
# 30       2.307864   2.734761
#
#                                           config path weight path
# 32   configfiles/generic/lframe_hwd_warmrestarts.toml        None
# 0   /home/luke/Code/SLR/src/configfiles/asl100/MVi...        None
# 25            configfiles/asl100/MViTv1_B/exp003.toml        None
# 28            configfiles/asl100/Swin3D_T/exp003.toml        None
# 26            configfiles/asl100/Swin3D_B/exp003.toml        None
# 31              configfiles/asl100/R3D_18/exp006.toml        None
# 36   configfiles/generic/hframe_hwd_warmrestarts.toml        None
# 1             configfiles/asl100/Swin3D_S/exp008.toml        None
# 27            configfiles/asl100/Swin3D_S/exp003.toml        None
# 29                 configfiles/asl100/S3D/exp046.toml        None
# 3                  configfiles/asl100/S3D/exp046.toml        None
# 30          configfiles/asl100/R(2+1)D_18/exp007.toml        None
# Asl300_cutoff_9
#          model exp no    run_id  No. frames           subset Test Top-1  \
# 20    MViTv2_S    001  nfwehytd          16  asl300_cutoff_9      65.42
# 21    MViTv1_B    001  8noyy5tz          16  asl300_cutoff_9      58.98
# 17    Swin3D_T    002  qx2nc2mj          16  asl300_cutoff_9      53.74
# 35         S3D    046      None          32  asl300_cutoff_9      54.49
# 19    Swin3D_B    002  bjc1br16          16  asl300_cutoff_9      50.30
# 18    Swin3D_S    002  hqxu4w1r          16  asl300_cutoff_9      50.60
# 24         S3D    002  vty80mdi          16  asl300_cutoff_9      51.95
# 22  R(2+1)D_18    002  7vrz6dvj          16  asl300_cutoff_9      38.02
# 23      R3D_18    002  xmadiwzp          16  asl300_cutoff_9      25.60
#
#    Test Top-5 Test Top-10 Val Top-1 Val Top-5 Val Top-10  best_val_acc  \
# 20      88.92       93.56     71.59     91.90      95.12     72.807991
# 21      84.88       89.82     65.04     87.46      91.34     65.371809
# 17      81.59       89.07     55.27     82.91      89.35     63.485017
# 35      80.69       87.28     58.93     84.68      89.90     65.815760
# 19      78.14       87.87     53.05     79.47      87.68     63.928968
# 18      80.39       87.57     56.38     83.91      91.68     62.264151
# 24      78.44       87.13     56.16     82.69      88.46     61.154273
# 22      67.07       77.10     42.62     69.92      80.24     45.615982
# 23      54.64       63.47     29.86     56.38      66.59     34.406215
#
#     best_val_loss  test_loss  \
# 20       1.113773   1.432866
# 21       1.457442   1.749123
# 17       1.973432   2.072897
# 35       1.871731   2.167438
# 19       1.974587   2.183009
# 18       1.871490   2.280623
# 24       2.039465   2.517264
# 22       2.998297   3.413699
# 23       3.348814   3.634662
#
#                                          config path weight path
# 20           configfiles/asl300/MViTv2_S/exp001.toml        None
# 21           configfiles/asl300/MViTv1_B/exp001.toml        None
# 17           configfiles/asl300/Swin3D_T/exp002.toml        None
# 35  configfiles/generic/hframe_hwd_warmrestarts.toml        None
# 19           configfiles/asl300/Swin3D_B/exp002.toml        None
# 18           configfiles/asl300/Swin3D_S/exp002.toml        None
# 24                configfiles/asl300/S3D/exp002.toml        None
# 22         configfiles/asl300/R(2+1)D_18/exp002.toml        None
# 23             configfiles/asl300/R3D_18/exp002.toml        None
# Asl1000_cutoff_9
#        model exp no    run_id  No. frames            subset Test Top-1  \
# 14  MViTv2_S    000  rc5m3meh          16  asl1000_cutoff_9      53.41
# 15  MViTv1_B    000  cdua0ddj          16  asl1000_cutoff_9      46.06
# 16       S3D    000  kpdu2hra          16  asl1000_cutoff_9      36.25
# 13  Swin3D_B    000  94kuihol          16  asl1000_cutoff_9      33.74
# 34       S3D    047  na70ufkk          32  asl1000_cutoff_9      37.74
# 11  Swin3D_T    000  rdmmkptp          16  asl1000_cutoff_9      23.24
# 12  Swin3D_S    000  n27qc5m6          16  asl1000_cutoff_9       8.80
#
#    Test Top-5 Test Top-10 Val Top-1 Val Top-5 Val Top-10  best_val_acc  \
# 14      81.77       87.79     56.71     83.96      89.69     58.645968
# 15      76.81       83.58     50.15     78.31      85.47     50.409659
# 16      67.80       77.08     38.72     68.26      77.75     46.313066
# 13      65.30       74.41     33.74     65.30      74.41     45.795602
# 34      67.86       77.72     38.68     70.89      80.08     50.927124
# 11      53.46       65.78     23.24     53.46      65.78     38.551100
# 12      25.16       37.47      8.80     25.16      37.47     24.665804
#
#     best_val_loss  test_loss  \
# 14       1.829793   2.027901
# 15       2.275253   2.457580
# 16       2.811866   2.900352
# 13       2.994693   3.142839
# 34       3.032371   3.246333
# 11       3.764943   3.888098
# 12       5.074488   5.114385
#
#                                          config path weight path
# 14          configfiles/asl1000/MViTv2_S/exp000.toml        None
# 15          configfiles/asl1000/MViTv1_B/exp000.toml        None
# 16               configfiles/asl1000/S3D/exp000.toml        None
# 13          configfiles/asl1000/Swin3D_B/exp000.toml        None
# 34  configfiles/generic/hframe_hwd_warmrestarts.toml        None
# 11          configfiles/asl1000/Swin3D_T/exp000.toml        None
# 12          configfiles/asl1000/Swin3D_S/exp000.toml        None
# Asl2000_cutoff_9
#          model exp no    run_id  No. frames            subset Test Top-1  \
# 9     MViTv2_S    000  fkv6kpik          16  asl2000_cutoff_9      38.87
# 4     Swin3D_S    000  cxh3q986          16  asl2000_cutoff_9      20.74
# 10    MViTv1_B    000  b73or9ez          16  asl2000_cutoff_9      19.94
# 7          S3D    000  olp97b32          16  asl2000_cutoff_9      19.62
# 33         S3D    048      None          32  asl2000_cutoff_9      17.12
# 5       R3D_18    000  sz27ivxv          16  asl2000_cutoff_9       6.15
# 6     Swin3D_B    000  x3n0l0p0          16  asl2000_cutoff_9       4.48
# 2     Swin3D_T    000  kct76mvs          16  asl2000_cutoff_9       3.09
# 8   R(2+1)D_18    000  mi1aom4x          16  asl2000_cutoff_9       6.32
#
#    Test Top-5 Test Top-10 Val Top-1 Val Top-5 Val Top-10  best_val_acc  \
# 9       71.62       79.82     38.87     71.62      79.82     42.036753
# 4       46.37       59.19     20.74     46.37      59.19     30.500255
# 10      46.96       59.64     19.94     46.96      59.64     27.207759
# 7       46.96       58.25     19.62     46.96      58.25     25.395610
# 33      41.02       53.28     18.58     44.18      56.05     28.075549
# 5       17.65       25.63      6.15     17.65      25.63     11.332312
# 6       13.75       21.22      4.48     13.75      21.22     12.787136
# 2       11.15       17.65      3.60     12.33      18.63     13.195508
# 8       18.20       25.63      6.32     18.20      25.63     10.847371
#
#     best_val_loss  test_loss  \
# 9        2.829839   2.916584
# 4        4.110085   4.238295
# 10       4.216844   4.324715
# 7        4.409879   4.434500
# 33       4.602991   4.762200
# 5        5.782174   5.857947
# 6        5.853937   5.960591
# 2        5.968048   6.030649
# 8        6.687963   6.841594
#
#                                          config path weight path
# 9           configfiles/asl2000/MViTv2_S/exp000.toml        None
# 4           configfiles/asl2000/Swin3D_S/exp000.toml        None
# 10          configfiles/asl2000/MViTv1_B/exp000.toml        None
# 7                configfiles/asl2000/S3D/exp000.toml        None
# 33  configfiles/generic/hframe_hwd_warmrestarts.toml        None
# 5             configfiles/asl2000/R3D_18/exp000.toml        None
# 6           configfiles/asl2000/Swin3D_B/exp000.toml        None
# 2           configfiles/asl2000/Swin3D_T/exp000.toml        None
# 8         configfiles/asl2000/R(2+1)D_18/exp000.toml        None

# %%
# Column used to select the best run per model/subset
SELECTION_COL = "best_val_acc"   # change to "best_val_loss" if needed

# Optional: if you want custom model names with \cite, set escape=False below
# and store the LaTeX string directly in the 'model' column.
# ==========================================================

def make_latex_table_for_subset(df, subset):
    """Select best run per model and return LaTeX table for one subset."""
    sub = df[df["subset"] == subset].copy()
    sub["model"] = sub["model"].astype(str).str.strip()

    # Convert selection column to numeric and drop rows with missing value
    sub[SELECTION_COL] = pd.to_numeric(sub[SELECTION_COL], errors="coerce")
    sub = sub.dropna(subset=[SELECTION_COL])

    # Select best run: highest accuracy or lowest loss
    if SELECTION_COL == "best_val_loss":
        idx = sub.groupby("model")[SELECTION_COL].idxmin()
    else:
        idx = sub.groupby("model")[SELECTION_COL].idxmax()
    best = sub.loc[idx].copy()

    # Keep only needed columns and rename
    best = best[["model", "Test Top-1", "Test Top-5", "Test Top-10"]].rename(
        columns={
            "model": "Model",
            "Test Top-1": "Acc@1",
            "Test Top-5": "Acc@5",
            "Test Top-10": "Acc@10",
        }
    )

    # Ensure metrics are numeric (to_latex will format them)
    for col in ["Acc@1", "Acc@5", "Acc@10"]:
        best[col] = pd.to_numeric(best[col], errors="coerce")

    # Generate LaTeX using .to_latex()
    latex = best.to_latex(
        index=False,
        na_rep="-",
        float_format="%.2f",
        caption=f"{subset} Results",
        label=f"tab:{subset.lower().replace('-', '_')}",
        position="htbp",
    )
    return latex


# Generate and print each table
for subset in subsets:
    print(f"% ===== Table for {subset} =====")
    print(make_latex_table_for_subset(df, subset))
    print("\n")   # blank line between tables
# Out:
# % ===== Table for asl100_cutoff_9 =====
# \begin{table}[htbp]
# \caption{asl100_cutoff_9 Results}
# \label{tab:asl100_cutoff_9}
# \begin{tabular}{lrrr}
# \toprule
# Model & Acc@1 & Acc@5 & Acc@10 \\
# \midrule
# MViTv1_B & 71.32 & 89.53 & 91.86 \\
# MViTv2_S & 79.46 & 91.86 & 95.35 \\
# R(2+1)D_18 & 48.06 & 77.13 & 86.05 \\
# R3D_18 & 55.04 & 82.17 & 88.76 \\
# S3D & 58.14 & 86.43 & 92.64 \\
# Swin3D_B & 54.26 & 82.56 & 91.09 \\
# Swin3D_S & 63.18 & 86.05 & 93.41 \\
# Swin3D_T & 60.08 & 85.27 & 93.80 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== Table for asl300_cutoff_9 =====
# \begin{table}[htbp]
# \caption{asl300_cutoff_9 Results}
# \label{tab:asl300_cutoff_9}
# \begin{tabular}{lrrr}
# \toprule
# Model & Acc@1 & Acc@5 & Acc@10 \\
# \midrule
# MViTv1_B & 58.98 & 84.88 & 89.82 \\
# MViTv2_S & 65.42 & 88.92 & 93.56 \\
# R(2+1)D_18 & 38.02 & 67.07 & 77.10 \\
# R3D_18 & 25.60 & 54.64 & 63.47 \\
# S3D & 54.49 & 80.69 & 87.28 \\
# Swin3D_B & 50.30 & 78.14 & 87.87 \\
# Swin3D_S & 50.60 & 80.39 & 87.57 \\
# Swin3D_T & 53.74 & 81.59 & 89.07 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== Table for asl1000_cutoff_9 =====
# \begin{table}[htbp]
# \caption{asl1000_cutoff_9 Results}
# \label{tab:asl1000_cutoff_9}
# \begin{tabular}{lrrr}
# \toprule
# Model & Acc@1 & Acc@5 & Acc@10 \\
# \midrule
# MViTv1_B & 46.06 & 76.81 & 83.58 \\
# MViTv2_S & 53.41 & 81.77 & 87.79 \\
# S3D & 37.74 & 67.86 & 77.72 \\
# Swin3D_B & 33.74 & 65.30 & 74.41 \\
# Swin3D_S & 8.80 & 25.16 & 37.47 \\
# Swin3D_T & 23.24 & 53.46 & 65.78 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
#
# % ===== Table for asl2000_cutoff_9 =====
# \begin{table}[htbp]
# \caption{asl2000_cutoff_9 Results}
# \label{tab:asl2000_cutoff_9}
# \begin{tabular}{lrrr}
# \toprule
# Model & Acc@1 & Acc@5 & Acc@10 \\
# \midrule
# MViTv1_B & 19.94 & 46.96 & 59.64 \\
# MViTv2_S & 38.87 & 71.62 & 79.82 \\
# R(2+1)D_18 & 6.32 & 18.20 & 25.63 \\
# R3D_18 & 6.15 & 17.65 & 25.63 \\
# S3D & 17.12 & 41.02 & 53.28 \\
# Swin3D_B & 4.48 & 13.75 & 21.22 \\
# Swin3D_S & 20.74 & 46.37 & 59.19 \\
# Swin3D_T & 3.09 & 11.15 & 17.65 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
print("Unique subset values:", df["subset"].unique())
print("Unique model values:", df["model"].unique())
print("Columns:", df.columns.tolist())
# Out:
# Unique subset values: ['asl100_cutoff_9' 'asl2000_cutoff_9' 'asl1000_cutoff_9' 'asl300_cutoff_9']
# Unique model values: ['MViTv2_S' 'Swin3D_S' 'Swin3D_T' 'S3D' 'R3D_18' 'Swin3D_B' 'R(2+1)D_18'
#  'MViTv1_B']
# Columns: ['model', 'exp no', 'run_id', 'No. frames', 'subset', 'Test Top-1', 'Test Top-5', 'Test Top-10', 'Val Top-1', 'Val Top-5', 'Val Top-10', 'best_val_acc', 'best_val_loss', 'test_loss', 'config path', 'weight path']
