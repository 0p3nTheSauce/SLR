# %% [markdown]
# # Statistics for WLASL: Pre-processed

# %%
import matplotlib.pyplot as plt

# locals
from src.run_types import RESULTS_OUTPUTS
from src.stats import (
    AVAIL_SETS,
    AVAIL_SPLITS,
    collect_instance_stats,
    instance_stats,
)
from src.video_dataset import get_labels_path, get_wlasl_info, load_data_from_json
from src.visualise2 import (
    plot_bar_chart,
    plot_bboxes_on_canvas,
    plot_dimension_distributions,
    save_fig,
    set_thesis_style,
    split_name_mapper,
)

# %% [markdown]
# ## From the WLASL GitHUB page
#
# Data Description
# -----------------
#
# * `gloss`: *str*, data file is structured/categorised based on sign gloss, or namely, labels.
#
# * `bbox`: *[int]*, bounding box detected using YOLOv3 of (xmin, ymin, xmax, ymax) convention. Following OpenCV convention, (0, 0) is the up-left corner.
#
# * `fps`: *int*, frame rate (=25) used to decode the video as in the paper.
#
# * `frame_start`: *int*, the starting frame of the gloss in the video (decoding
# with FPS=25), *indexed from 1*.
#
# * `frame_end`: *int*, the ending frame of the gloss in the video (decoding with FPS=25). -1 indicates the gloss ends at the last frame of the video.
#
# * `instance_id`: *int*, id of the instance in the same class/gloss.
#
# * `signer_id`: *int*, id of the signer.
#
# * `source`: *str*, a string identifier for the source site.
#
# * `split`: *str*, indicates sample belongs to which subset.
#
# * `url`: *str*, used for video downloading.
#
# * `variation_id`: *int*, id for dialect (indexed from 0).
#
# * `video_id`: *str*, a unique video identifier.
#
#
# ### Additional info:
#
# * The videos come pre-cut from the original youtube videos, therefore, the video_id is essentially a unique identifier for each instance
#
# * There are some issues with the labelling, especially where certain frame start and ends are way too high. These are set to 0 and last frame respectively
#
#
# * All precut video clips have a width and height of 256 pixels.
#
# * Modified bounding boxes with yolov8
#
#
# ### Naming convention:
# For the naming of different functions, 'set' and 'split' can somtimes be used interchangibly to mean different things, which can be confusing. So for all code written by me,
# * **SPLIT**: A split of WLASL, one of asl100, asl300, asl1000 and asl2000
# * **SET**: A subset of a given wlasl split, one of train, val test

# %%
split_idx = 3  # change for different split
set_idx = 1  # change for different set
split_options: list[AVAIL_SPLITS] = [
    "asl100", "asl300", "asl1000", "asl2000", "asl100_bottom", "asl100_worst",
]
set_options: list[AVAIL_SETS] = ["train", "test", "val"]
split_name: AVAIL_SPLITS = split_options[split_idx]
set_name: AVAIL_SETS = set_options[set_idx]

set_thesis_style()

project_name = "dataset_analysis"
output_dir = RESULTS_OUTPUTS / project_name

# %%
set_path_info = get_wlasl_info(split_name, set_name)
set_path = get_labels_path(set_name, set_path_info["labels"], set_path_info["label_suff"])
preproc_set = load_data_from_json(set_path, policy="strict")

print(f"Set: {split_name} / {set_name}")
# Out:
# Set: asl2000 / test

# %% [markdown]
# ## Stats

# %%
set_stats = collect_instance_stats(preproc_set)
print(f"Num instances: {set_stats['num_instances']}")
# Out:
# Num instances: 2879

# %%
# (stats key, display label, unit, tick-label thinning step -- None to show every label)
distribution_metrics: list[tuple[str, str, str, int | None]] = [
    ("length_distribution", "Video Length", "frames", 5),
    ("signers_distribution", "Signer", "signer id", 5),
    ("source_distribution", "Video Source", "source", None),
    # ("variation_distribution", "Variation", "dialect id", None),
]


def plot_distribution_metrics(
    stats_obj: instance_stats,
    metrics: list[tuple[str, str, str, int | None]],
    title_suffix: str,
    file_prefix: str,
) -> None:
    """Bar-chart each (key, label, unit, tick_step) metric in `metrics` from `stats_obj`."""
    for key, label, unit, tick_step in metrics:
        histogram = stats_obj[key]  # type: ignore[literal-required]
        sorted_items = sorted(histogram.items(), key=lambda item: item[0])
        categories = [str(value) for value, _ in sorted_items]
        counts = [count for _, count in sorted_items]

        fig, ax = plot_bar_chart(
            categories,
            counts,
            title=f"{label} Distribution: {title_suffix}",
            xlabel=f"{label} ({unit})",
            ylabel="Count",
            show_values=False,
        )
        if tick_step is not None:
            for i, tick_label in enumerate(ax.get_xticklabels()):
                tick_label.set_visible(i % tick_step == 0)
        save_fig(fig, output_dir / f"{file_prefix}_{key}.pdf")
        plt.show()

# %%
plot_distribution_metrics(
    set_stats,
    distribution_metrics,
    title_suffix=f"{split_name_mapper(split_name)} / {set_name.capitalize()}",
    file_prefix=f"{split_name}_{set_name}",
)

# %% [markdown]
# ### Video URL distribution
#
# `url_distribution` is near-unique per instance (each video is its own URL), so
# a full bar chart of it would be one bin per instance -- not a useful plot at
# this scale. What is worth checking is whether any URL is reused across
# multiple instances (e.g. one video re-cut for several glosses).

# %%
url_distribution = set_stats["url_distribution"]
missing_url_count = url_distribution.get("", 0)
reused_urls = {url: count for url, count in url_distribution.items() if count > 1 and url}

print(f"Num unique video URLs: {len(url_distribution)} (total instances: {set_stats['num_instances']})")
if missing_url_count:
    print(f"{missing_url_count} instances have no recorded URL (empty string).")
if reused_urls:
    top_reused = sorted(reused_urls.items(), key=lambda item: item[1], reverse=True)[:10]
    print(f"{len(reused_urls)} URLs (excluding missing) are reused across multiple instances, e.g.:")
    for url, count in top_reused:
        print(f"  {count}x  {url}")
else:
    print("No URL is reused across multiple instances.")
# Out:
# Num unique video URLs: 2316 (total instances: 2879)
# 537 instances have no recorded URL (empty string).
# 18 URLs (excluding missing) are reused across multiple instances, e.g.:
#   5x  https://www.youtube.com/watch?v=sErq0TJMKEo
#   4x  https://www.youtube.com/watch?v=bq-HmgjGzmw
#   3x  https://www.youtube.com/watch?v=4Nh1iFv2BMc
#   3x  https://www.youtube.com/watch?v=lvqGMGFmuV4
#   3x  https://www.youtube.com/watch?v=pc0-gVEETVg
#   3x  https://www.youtube.com/watch?v=F5Wef1_PtLk
#   2x  https://www.signingsavvy.com/signs/mp4/5/5971.mp4
#   2x  https://www.youtube.com/watch?v=WGfiiDgrq1I
#   2x  https://www.youtube.com/watch?v=CSj7IScvZnE
#   2x  https://www.youtube.com/watch?v=2DblIQ5n6xk

# %% [markdown]
# ### BBox dimensions and per-class average bbox

# %%
fig, axes = plot_dimension_distributions(
    preproc_set,
    title=f"BBox Dimension Distributions: {split_name_mapper(split_name)} / {set_name.capitalize()}",
)
save_fig(fig, output_dir / f"bbox_dimensions_{split_name}_{set_name}.pdf")
plt.show()

# %%
fig, ax = plot_bboxes_on_canvas(
    preproc_set,
    title=f"Average bounding box by class: {split_name_mapper(split_name)} / {set_name.capitalize()}",
)
save_fig(fig, output_dir / f"bboxes_{split_name}_{set_name}.pdf")
plt.show()

# %% [markdown]
# ## Per-gloss drill-down
#
# Pick a single gloss from the currently loaded set and plot the same
# distributions, scoped to just that gloss's instances -- e.g. to spot a
# class with an unusually skewed signer mix. At this scale (one gloss, a
# handful of instances) the URL distribution is actually informative, unlike
# at the whole-set level above, so it's included here.

# %%
gloss_name = "book"  # change for a different gloss
gloss_instances = [inst for inst in preproc_set if inst.label_name == gloss_name]
gloss_stats = collect_instance_stats(gloss_instances)

print(f"Gloss: {gloss_name}")
print(f"Num instances: {gloss_stats['num_instances']}")

gloss_metrics = [*distribution_metrics, ("url_distribution", "Video", "url", None)]
# plot_distribution_metrics(
#     gloss_stats,
#     gloss_metrics,
#     title_suffix=f'{split_name_mapper(split_name)} / {set_name.capitalize()} / "{gloss_name}"',
#     file_prefix=f"{split_name}_{set_name}_{gloss_name}",
# )
# Out:
# Gloss: book
# Num instances: 4

# %% [markdown]
# ## Cross-split summary
#
# Per-set (train/val/test) instance/signer count ranges across every split in
# `split_options`, via `src.stats.create_instances_table`.

# %%
from IPython.display import display

from src.configs import get_class_list
from src.preprocess import WLASLClass
from src.stats import (
    create_instances_table,
    get_set_stats,
    reverse_preproc_format,
    set_stats,
)


def load_per_set_stats(split: AVAIL_SPLITS, classes: list[str]) -> dict[AVAIL_SETS, set_stats]:
    """Load train/test/val instance stats for one split, from the preprocessed labels."""
    per_set: dict[AVAIL_SETS, set_stats] = {}
    for s in set_options:
        info = get_wlasl_info(split, s)
        path = get_labels_path(s, info["labels"], info["label_suff"])
        instances = load_data_from_json(path, policy="strict")
        glosses = reverse_preproc_format(instances, classes=classes)
        per_set[s] = get_set_stats([WLASLClass.model_validate(g) for g in glosses])
    return per_set


classes = get_class_list()
for split in split_options:
    print(f"Split: {split_name_mapper(split)}")
    display(create_instances_table(load_per_set_stats(split, classes)))
# Out:
# Split: WLASL-100
#   Set name  Num instances  Num signers instances per gloss signers per gloss
# 0    train           1442           91           [12 - 30]          [7 - 15]
# 1     test            258           56             [2 - 5]           [2 - 4]
# 2      val            338           69             [3 - 6]           [2 - 6]
# Split: WLASL-300
#   Set name  Num instances  Num signers instances per gloss signers per gloss
# 0    train           3549          104            [9 - 30]          [5 - 15]
# 1     test            668           74             [2 - 5]           [1 - 4]
# 2      val            901           88             [2 - 6]           [2 - 6]
# Split: WLASL-1000
#   Set name  Num instances  Num signers instances per gloss signers per gloss
# 0    train           8978          113            [6 - 30]          [4 - 15]
# 1     test           1876           89             [1 - 5]           [1 - 4]
# ...

# %% [markdown]
# ## Unprocessed data: LaTeX summary tables
#
# Everything above uses the *preprocessed* labels (post-crop, post frame-range
# fixes). This section instead loads the raw/original WLASL split JSON
# (`SPLIT_DIR`), which only exists for the four original splits (not the
# `_cutoff_9`/`_bottom`/`_worst` variants -- hence the separate `raw_split_name`
# parameter below rather than reusing `split_name`), and produces the two
# LaTeX summary tables used in the thesis: one per-set (train/val/test) row of
# instance/signer/class counts for the whole split, and one per-gloss row of
# instance/signer/variation counts for a chosen set.

# %%
import json

from src.run_types import SPLIT_DIR
from src.stats import (
    create_class_stats_table,
    create_split_summary_table,
    get_split_stats,
)

raw_split_options: list[AVAIL_SPLITS] = ["asl100", "asl300", "asl1000", "asl2000"]
raw_split_name: AVAIL_SPLITS = raw_split_options[3]  # change for a different split
raw_set_name: AVAIL_SETS = "train"  # change for the per-gloss table below

with open(SPLIT_DIR / f"{raw_split_name}.json") as f:
    raw_split = [WLASLClass.model_validate(c) for c in json.load(f)]

raw_split_stats = get_split_stats(raw_split)
print(f"Num classes: {raw_split_stats['num_classes']}")
print(f"Num instances: {raw_split_stats['num_instances']}")
print(f"Num signers: {raw_split_stats['num_signers']}")
# Out:
# Num classes: 2000
# Num instances: 21095
# Num signers: 119

# %% [markdown]
# #### Per-set summary table

# %%
split_table = create_split_summary_table(raw_split_stats)
split_latex = split_table.to_latex(
    index=False,
    caption=f"Statistics summary for split {split_name_mapper(raw_split_name)}.",
    label=f"tab:stats_{raw_split_name}",
)

# output_dir.mkdir(parents=True, exist_ok=True)
# with open(output_dir / f"split_summary_{raw_split_name}.tex", "w") as f:
#     f.write(split_latex)
print(split_latex)
# Out:
# \begin{table}
# \caption{Statistics summary for split WLASL-2000.}
# \label{tab:stats_asl2000}
# \begin{tabular}{lrrr}
# \toprule
# Set & Instances & Signers & Classes \\
# \midrule
# train & 14296 & 117 & 2000 \\
# val & 3920 & 109 & 2000 \\
# test & 2879 & 105 & 2000 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# #### Per-gloss class stats table
#
# One row per gloss -- can be large (up to `num_classes` rows), so only a
# preview is displayed; the full table is written to the `.tex` file.

# %%
class_table = create_class_stats_table(raw_split_stats["per_set_stats"][raw_set_name])
print(f"Per-gloss class stats: {len(class_table)} rows")
display(class_table.head(10))

class_latex = class_table.to_latex(
    index=False,
    caption=f"Class-level statistics for {raw_set_name} ({split_name_mapper(raw_split_name)} split).",
    label=f"tab:stats_class_{raw_split_name}_{raw_set_name}",
)
class_tex_path = output_dir / f"class_stats_{raw_split_name}_{raw_set_name}.tex"
# with open(class_tex_path, "w") as f:
#     f.write(class_latex)
print(f"Saved LaTeX table to {class_tex_path}")
# Out:
# Per-gloss class stats: 2000 rows
#       Gloss  Instances  Signers  Variations
# 0      book         30       14           1
# 1     drink         25       15           1
# 2  computer         20       12           3
# 3    before         18       13           2
# 4     chair         19       11           1
# 5        go         19       13           2
# 6   clothes         18       10           1
# 7       who         18       15           1
# 8     candy         17       13           2
# 9    cousin         16       10           1
# Saved LaTeX table to /home/luke/Code/SLR/src/results/outputs/dataset_analysis/class_stats_asl2000_train.tex
